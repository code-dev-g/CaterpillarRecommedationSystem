# %%
import pandas as pd

# %%
data = pd.read_csv('../DATA/PartsRecommendation.csv')

# %%
data.head()
# Out:
#                    INVOICE_ID INVOICE_DATE PART_NUMBER  \
# 0  U370/9670114009-3350006692   2020-06-17      5O7126
# 1        M060/M060-3073812939   2020-04-30      3N6968
# 2  U370/9670558168-3300504198   2021-07-20      1U0931
# 3            W700/CTS33550363   2020-08-14      0L0181
# 4                C090/7F87195   2022-04-30     30K3389
#
#                          SERVICE                    PART_NAME SALES_MODEL
# 0      Drivetrain-Brakes-Rebuild               Screen Filters        289Y
# 1      Drivetrain-Brakes-Rebuild                      Gaskets        289Y
# 2      Drivetrain-Brakes-Rebuild  Seals, Gaskets, and O-Rings        289Y
# 3        Drivetrain-Axle-Rebuild             Bolts and Screws        488V
# 4  Engine-Injector Group-Rebuild                          NaN        W70M

# %%
data.describe()
# Out:
#              INVOICE_ID INVOICE_DATE PART_NUMBER                    SERVICE  \
# count             94627        94627       94627                      94627
# unique            21407         1549        3224                          8
# top     W180/LJY0944951   2022-12-29     7379849  Drivetrain-Brakes-Rebuild
# freq                559          723        4095                      52728
#
#                           PART_NAME SALES_MODEL
# count                         93603       94627
# unique                          190           8
# top     Seals, Gaskets, and O-Rings        289Y
# freq                          23470       52728

# %%
data.head()
# Out:
#                    INVOICE_ID INVOICE_DATE PART_NUMBER  \
# 0  U370/9670114009-3350006692   2020-06-17      5O7126
# 1        M060/M060-3073812939   2020-04-30      3N6968
# 2  U370/9670558168-3300504198   2021-07-20      1U0931
# 3            W700/CTS33550363   2020-08-14      0L0181
# 4                C090/7F87195   2022-04-30     30K3389
#
#                          SERVICE                    PART_NAME SALES_MODEL
# 0      Drivetrain-Brakes-Rebuild               Screen Filters        289Y
# 1      Drivetrain-Brakes-Rebuild                      Gaskets        289Y
# 2      Drivetrain-Brakes-Rebuild  Seals, Gaskets, and O-Rings        289Y
# 3        Drivetrain-Axle-Rebuild             Bolts and Screws        488V
# 4  Engine-Injector Group-Rebuild                          NaN        W70M

# %%
data.isna().sum()
# Out:
# INVOICE_ID         0
# INVOICE_DATE       0
# PART_NUMBER        0
# SERVICE            0
# PART_NAME       1024
# SALES_MODEL        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.drop(columns=["SERVICE"], inplace=True)

# %%
data.drop(columns=["PART_NUMBER"], inplace=True)

# %%
data.drop(columns=["INVOICE_DATE"], inplace=True)

# %%
data.head()
# Out:
#                    INVOICE_ID                      PART_NAME SALES_MODEL
# 0  U370/9670114009-3350006692                 Screen Filters        289Y
# 1        M060/M060-3073812939                        Gaskets        289Y
# 2  U370/9670558168-3300504198    Seals, Gaskets, and O-Rings        289Y
# 3            W700/CTS33550363               Bolts and Screws        488V
# 5           E050/003503232507  Kit - Drivetrain and Steering        289Y

# %%
for id, order in data.iterrows():
    if 'and' in order["PART_NAME"]:
        order["PART_NAME"] = order["PART_NAME"].replace(', and', ',')
    # order["PART_NAME"] = order["PART_NAME"].replace(' ', '')
    order["PART_NAME"] = order["PART_NAME"].split(',')
    order["PART_NAME"] = [x.strip() for x in order["PART_NAME"] if x!='' and x!=' ']

# %%
data.head()
# Out:
#                    INVOICE_ID                     PART_NAME SALES_MODEL
# 0  U370/9670114009-3350006692              [Screen Filters]        289Y
# 1        M060/M060-3073812939                     [Gaskets]        289Y
# 2  U370/9670558168-3300504198     [Seals, Gaskets, O-Rings]        289Y
# 3            W700/CTS33550363               [Bolts, Screws]        488V
# 5           E050/003503232507  [Kit - Drivetrain, Steering]        289Y

# %%
newData = pd.DataFrame(columns=data.columns)

for _, order in data.iterrows():
    if not (newData["INVOICE_ID"] == order["INVOICE_ID"]).any():
        newData = pd.concat([pd.DataFrame([order], columns=data.columns), newData], ignore_index=True)
    else:
        invoice_id = order["INVOICE_ID"]
        parts = newData.loc[newData["INVOICE_ID"] == invoice_id, "PART_NAME"].tolist()
        parts = parts[0]
        for part in order["PART_NAME"]:
            if part not in parts:
                parts.append(part)
        newData.loc[newData["INVOICE_ID"] == invoice_id, "PART_NAME"] = [sorted(parts)]
        # print(parts)

# %%
newData
# Out:
#                        INVOICE_ID  \
# 0                     R530/823396
# 1                    U010/YX77258
# 2                    C360/0079426
# 3                    C730/ZX00345
# 4      U370/9670135921-3300689042
# ...                           ...
# 21185           E050/003503232507
# 21186            W700/CTS33550363
# 21187  U370/9670558168-3300504198
# 21188        M060/M060-3073812939
# 21189  U370/9670114009-3350006692
#
#                                                PART_NAME SALES_MODEL
# 0                           [Kit - Drivetrain, Steering]        289Y
# 1                                               [Grease]         665
# 2                                               [Grease]         665
# 3                                               [Grease]         665
# 4                           [Kit - Drivetrain, Steering]        289Y
# ...                                                  ...         ...
# 21185                       [Kit - Drivetrain, Steering]        289Y
# 21186  [Bolts, Breathers, Clamps, Clips, Driveshafts,...        488V
# 21187  [Bearings, Breathers, Clamps, Clips, DT Valve ...        289Y
# 21188  [Bolts, Caps, Fasteners Studs, Gaskets, Hose a...        289Y
# 21189  [Accumulators, Breathers, Dryers, Dust Ejector...        289Y
#
# [21190 rows x 3 columns]

# %%
newData.drop(columns=["INVOICE_ID"], inplace=True)

# %%
newData.describe()
# Out:
#                   PART_NAME SALES_MODEL
# count                 21190       21190
# unique                 3166           8
# top     [Kit - Maintenance]        289Y
# freq                   3858       10944
